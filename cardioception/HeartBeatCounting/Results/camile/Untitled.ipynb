# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
oxi = np.load('camile_0.npy')

# %%
plt.figure(figsize=(12, 4))
plt.plot(oxi[0, :])
plt.plot(oxi[1, :]*100)
plt.plot(oxi[2, :]*100)

# %%
df = pd.read_csv('camile.txt')

# %%
nbeats = []
for i in range(7):
    oxi = np.load('camile_' + str(i) + '.npy')
    nbeats.append(np.sum(oxi[1, np.where(oxi[2, :] == 1)[0][0] : np.where(oxi[2, :] == 2)[0][0]]))
df['nbeats'] = nbeats

# %%
df['Duration'] = np.array([20, 25, 30, 35, 40, 45, 50])

# %%
1-((np.abs(df.nbeats - df.Reported))/((df.nbeats + df.Reported)/2))
# Out:
# 0    0.636364
# 1    0.333333
# 2    0.350649
# 3    0.494505
# 4    0.250000
# 5    0.355932
# 6    0.191489
# dtype: float64

# %%
l = []
for i in range(1000):
    l.append(1-((np.abs(40 - i))/((40 + i)/2)))

# %%
plt.figure(figsize=(12, 4))
plt.plot(l)

# %%
1-((np.abs(df.nbeats - df.Reported))/((df.nbeats + df.Reported)/2))
