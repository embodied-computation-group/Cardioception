# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
oxi = np.load('camile_0.npy')

# %%
plt.figure(figsize=(12, 4))
plt.plot(oxi[0, :])
plt.plot(oxi[1, :]*100)
plt.plot(oxi[2, :]*100)

# %%
oxi[2, :]

# %%
df = pd.read_csv('camile.txt')

# %%
df
# Out:
#    Unnamed: 0  nTrial  Reported  Confidence  ConfidenceRT
# 0           0       0        18           5         3.787
# 1           0       1        22           4         7.245
# 2           0       2        26           4         2.718
# 3           0       3        34           3         7.169
# 4           0       4        15           4         2.701
# 5           0       5        20           4         5.234
# 6           0       6        28           4         4.951
