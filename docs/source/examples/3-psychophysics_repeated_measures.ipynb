# %% [markdown]
# (psychophysics_repeated_measures)=
# # Fitting psychometric functions for repeated measures
# :::{post} Aug 17, 2022
# :tags: psychophysics, heart rate discrimination
# :category: modelling
# :author: Nicolas Legrand
# :::
#
# ```{warning}
# Under construction.
# ```

# %%
# %%capture
import sys

if 'google.colab' in sys.modules:
    ! pip install arviz
    ! pip install pymc

# %%
import aesara.tensor as at
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import norm

import pymc as pm

sns.set_context('talk')
