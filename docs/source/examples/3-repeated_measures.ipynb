# %% [markdown]
# **Author**: Nicolas Legrand <nicolas.legrand@cfin.au.dk>
#
# The model is adapted from https://github.com/pymc-devs/resources/blob/master/BCM/CaseStudies/PsychophysicalFunctions.ipynb

# %%
# %%capture
import sys
if 'google.colab' in sys.modules:
    ! pip install arviz
    ! pip install pymc

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import norm

import pymc as pm
import aesara.tensor as at

sns.set_context('talk')

# %% [markdown]
# # Fitting psychometric functions for repeated measures
#
# ```{warning}
# Under construction.
# ```
